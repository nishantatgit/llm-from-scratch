# %%
import urllib.request
import re
from collections import Counter
url = "https://gutenberg.org/cache/epub/345/pg345.txt"

with urllib.request.urlopen(url) as response:
    text = response.read().decode("utf-8")

start_pat = r"\*\*\* START OF TH(IS|E) PROJECT GUTENBERG EBOOK.*?\*\*\*"
end_pat   = r"\*\*\* END OF TH(IS|E) PROJECT GUTENBERG EBOOK.*?\*\*\*"

start = re.search(start_pat, text)
end   = re.search(end_pat, text)
text = text[start.end():end.start()].strip()


print(f"{text[:500]}\n")

tokens_raw = re.split(r'([,.:;?_!"()\'“”‘’]|--|\s)', text)
print(f"{tokens_raw[:20]}")
print(f"Total tokens count : {len(tokens_raw)}\n")

token_set = set(tokens_raw)
print(token_set)
print(f"Total distinct tokens count : {len(token_set)}\n")


preprocessed = sorted([item.strip() for item in token_set if item.strip()])
print("preprocessed", preprocessed[:200])
print(f"Total distinct preprocessed tokens count : {len(preprocessed)}\n")

vocab = {token:i for i,token in enumerate(preprocessed)}
print(f"vocab : {vocab}")
# Out:
# DRACULA
#
#                                   _by_
#
#                               Bram Stoker
#
#                         [Illustration: colophon]
#
#                                 NEW YORK
#
#                             GROSSET & DUNLAP
#
#                               _Publishers_
#
#       Copyright, 1897, in the United States of America, according
#                    to Act of Congress, by Bram Stoker
#
#                         [_All rights reserved._]
#
#                       PRINTED IN THE
#
# ['DRACULA', '\r', '', '\n', '', '\r', '', '\n', '', ' ', '', ' ', '', ' ', '', ' ', '', ' ', '', ' ']
# Total tokens count : 429083
#
# {'', 'resistance', 'inwardly', 'Tokay', 'sceptical', 'unrecorded', 'among', 'displeased', 'calmness', 'brushing', 'strewn', 'boots', 'grano', 'sto', 'Diary', 'insisted', 'althegither', 'half-dozen', 'West', 'onion', 'month', 'facing', 'scandal', 'Czarina', 'grace', 'sickly', 'requirements', 'heavily', 'puma', 'nethermost', 'opiate', 'wampyr', 'chance', 'hordes', 'Sea', 'utterance', 'MURRAY', 'scudded', 'occupied', 'holiday', 'Blow', 'signature', 'conveyance', 'divided', 'opened', 'holds', 'wynds', 'severed', 'rail', 'possible', 'unprepared', 'nationality', 'revealed', 'level', 'good-humoured', 'corpse', 'period', 'stertorous', 'trembling', 'putty', 'happed', 'snatched', 'tally', 'Mate', 'beetling', 'previously', 'experienced', 'accused', 'Lady', 'ardour', 'pressing', 'inserted', 'levelled', 'snap', 'face', 'sheets', 'suspected', 'bride', 'guilt', 'performances', 'earliest', 'accuracy', '.', 'threes', 'up-end', 'story', 'changed', 'thread', 'a-lookin', 'tidings', 'encouragement', 'discovering', 'pond', 'fits', 'reclining', 'distrustful', 'wharf', 'humans', 'mine', 'latest', 'M', 'enthusiastically', 'amongst', 'impetuosity', 'boomed', 'material', 'itself', 'unison', 'given', 'whistled', 'laying', 'negative', 'Straightway', 'Of', 'sure', 'hide', 'restored', 'fooled', 'listening', 'campaign', 'chaplain', 'fellows', 'fierceness', 'load', 'comin', 'Honourable', 'calm', 'bestrewed', 'arguments', 'breathless', 'consignment', 'druv', 'hobby', 'rolled', 'quiet', 'scythe', 'endured', 'standard', 'sophistic', 'wind', 'genuine', 'folded', 'egoist', 'avenue', 'mortmain', 'library', 'uneasily', 'deputy', 'Lay', 'poured', 'wear', 'dreamless', 'lowest', 'coincidence', 'BY', 'interrupt', 'eventually', 'pine-clad', 'den', 'towel', 'fat', 'fear', 'piercingly', 'smith', 'suavely', 'Send', 'yields', 'horrorstruck', 'broad', 'wrenching', 'winter', 'yew-tree', 'ebb', 'chink', 'em', 'tablets', 'gard', 'depression', 'scrap', 'temperament', 'frayed', 'Medusa', 'tiniest', 'Aitetropos', 'reflected', 'hindrance', 'dictionary', 'Him', 'Count', 'exactness', 'Burial', 'stepped', 'wreaths', 'image', 'point-blank', 'stethoscope', 'northern', 'bullying', 'trifling', 'mind', 'tuas', 'wink', 'proceed', 'considerate', 'smoked', 'author', 'flared', 'Twarn', 'proving', 'pall', 'encountered', 'large', 'Swales', 'explored', 'dictatorial', 'X', 'tries', 'dreary', 'arched', 'ESCAPED', 'disgusted', 'hiding-place', 'obliged', 'Blyme', 'deliberately', 'metallic', 'dozing', 'caught', 'apart', 'wafts', 'turned', 'ended', 'swore', '13', 'frowning', 'deemed', 'swords', 'wakes', 'fused', 'winningly', 'drawn', 'whetting', 'star', 'hunger', 'flown', 'wailed', 'hints', 'towered', 'taken', 'Paris', 'responsible', 'fancied', 'bus', 'sudden', 'optical', 'expanse', 'anguish', 'Only', 'yawing', 'weak-looking', 'bogles', 'palms', 'Outlined', 'wickedness', 'incurring', 'eyelashes', 'signal', 'excitable', 'awaked', 'scrutinised', 'belt', 'deliberate', 'gossips', 'weakening', 'pulling', 'stages', 'spark', 'coffee-shop', 'experiences', 'doggedly', 'Hull', 'Hildesheim', 'bone', 'mantle', 'title', 'Pit', 'ART', 'others', 'handled', 'precaution', 'create', 'oars', 'Survey', 'obscured', 'sands', 'entered', 'effacing', 'chicken-feed', 'merely', 'Petrofsky', 'vif', 'steam', 'vendor', 'visiting', 'held', 'trick', 'future', 'wheeling', 'sitting', 'quay', 'Y', 'physicians', 'telephoned', 'liberties', 'lapping', 'built', 'sir', 'unchanged', 'path', 'LIFE', 'COURT', 'Dead', 'occupy', 'lightning', 'scytheman', 'hunters', 'homicidal', 'resolute', 'Ville', 'dangerously', 'digression', 'subject', 'alight', 'stop', 'horse', 'sail', 'significantly', 'enabled', 'tumbled', 'script', 'Two', 'resisting', 'Arsk', 'rides', 'burning', 'hoodwink', 'relief', 'unasked', 'yearn', 'enduring', 'point', 'replenish', 'quickness', 'or', 'know', 'greet', 'supposed', 'sea-mist', 'refraction', 'tigers', 'perfect', 'dustiness', 'impossible', 'clasp', 'powerful', 'strewments', 'pours', 'smallest', 'That', 'consequent', 'malignit ...
# Total distinct tokens count : 10417
#
# preprocessed ['!', '&', '(', ')', '*', ',', '--', '-tails', '-the-wisp', '.', '000', '1', '10', '11', '12', '12th', '13', '14', '15', '16', '17', '1777', '17s', '17th', '18', '1854', '1873', '1897', '19', '197', '1st', '2', '20', '21', '22', '23', '24', '24th', '25', '26', '27', '28', '29', '3', '3-4', '30', '31', '33', '34', '347', '35', '4', '40', '45', '46', '47th', '5', '50', '500', '59', '6', '7', '70', '8', '9', '9d', ':', ';', '?', 'A', 'ABRAHAM', 'ADVENTURE', 'AGATHA', 'AMALGAMATION', 'AND', 'ANNEXATION', 'ANOTHER', 'ART', 'ARTHUR', 'AT', 'AUGUST', 'Abbey', 'About', 'Abraham', 'Abramoff', 'Accurate', 'Acherontia', 'Act', 'Action', 'Adelphi', 'Admiralty', 'Afraid', 'Africa', 'After', 'Again', 'Agatha', 'Agreed', 'Ah', 'Aha', 'Aitetropos', 'Alas', 'Albemarle', 'All', 'Alley', 'Almanac', 'Almighty', 'Alone', 'Alphabetical', 'Already', 'Also', 'Am', 'Amen', 'America', 'American', 'Americanism', 'Amid', 'Amongst', 'Amsterdam', 'An', 'And', 'Andersen', 'Andres', 'Andrew', 'Angel', 'Angels', 'Another', 'Answer', 'Antwerp', 'Any', 'April', 'Arabian', 'Archibald', 'Archimedes', 'Archipelago', 'Are', 'Arlington', 'Arminius', 'Arminus', 'Army', 'Arpad', 'Arrived', 'Arsk', 'Art', 'Arthur', 'As', 'Asia', 'Ask', 'Asylum', 'At', 'Attila', 'Aud', 'August', 'Austrian', 'Authors', 'Avar', 'Away', 'Ay', 'Aërated', 'B', 'BARBICAN', 'BILLINGTON', 'BY', 'Back', 'Backsheesh', 'Bah', 'Bank', 'Bartel', 'Bats', 'Bay', 'Be', 'Because', 'Before', 'Behind', 'Behold', 'Being', 'Believe', 'Berkeley', 'Bermondsey', 'Berserkers', 'Bersicker', 'Besides', 'Bethnal', 'Better', 'Between', 'Beware', 'Beyond', 'Big', 'Bilder', 'Billington', 'Billreuth', 'Biscay', 'Bistritz', 'Bistritza', 'Black', 'Black-Sea-bound', 'Bleeding', 'Bless', 'Blessed', 'Blood', 'Bloofer']
# Total distinct preprocessed tokens count : 10413
#
# vocab : {'!': 0, '&': 1, '(': 2, ')': 3, '*': 4, ',': 5, '--': 6, '-tails': 7, '-the-wisp': 8, '.': 9, '000': 10, '1': 11, '10': 12, '11': 13, '12': 14, '12th': 15, '13': 16, '14': 17, '15': 18, '16': 19, '17': 20, '1777': 21, '17s': 22, '17th': 23, '18': 24, '1854': 25, '1873': 26, '1897': 27, '19': 28, '197': 29, '1st': 30, '2': 31, '20': 32, '21': 33, '22': 34, '23': 35, '24': 36, '24th': 37, '25': 38, '26': 39, '27': 40, '28': 41, '29': 42, '3': 43, '3-4': 44, '30': 45, '31': 46, '33': 47, '34': 48, '347': 49, '35': 50, '4': 51, '40': 52, '45': 53, '46': 54, '47th': 55, '5': 56, '50': 57, '500': 58, '59': 59, '6': 60, '7': 61, '70': 62, '8': 63, '9': 64, '9d': 65, ':': 66, ';': 67, '?': 68, 'A': 69, 'ABRAHAM': 70, 'ADVENTURE': 71, 'AGATHA': 72, 'AMALGAMATION': 73, 'AND': 74, 'ANNEXATION': 75, 'ANOTHER': 76, 'ART': 77, 'ARTHUR': 78, 'AT': 79, 'AUGUST': 80, 'Abbey': 81, 'About': 82, 'Abraham': 83, 'Abramoff': 84, 'Accurate': 85, 'Acherontia': 86, 'Act': 87, 'Action': 88, 'Adelphi': 89, 'Admiralty': 90, 'Afraid': 91, 'Africa': 92, 'After': 93, 'Again': 94, 'Agatha': 95, 'Agreed': 96, 'Ah': 97, 'Aha': 98, 'Aitetropos': 99, 'Alas': 100, 'Albemarle': 101, 'All': 102, 'Alley': 103, 'Almanac': 104, 'Almighty': 105, 'Alone': 106, 'Alphabetical': 107, 'Already': 108, 'Also': 109, 'Am': 110, 'Amen': 111, 'America': 112, 'American': 113, 'Americanism': 114, 'Amid': 115, 'Amongst': 116, 'Amsterdam': 117, 'An': 118, 'And': 119, 'Andersen': 120, 'Andres': 121, 'Andrew': 122, 'Angel': 123, 'Angels': 124, 'Another': 125, 'Answer': 126, 'Antwerp': 127, 'Any': 128, 'April': 129, 'Arabian': 130, 'Archibald': 131, 'Archimedes': 132, 'Archipelago': 133, 'Are': 134, 'Arlington': 135, 'Arminius': 136, 'Arminus': 137, 'Army': 138, 'Arpad': 139, 'Arrived': 140, 'Arsk': 141, 'Art': 142, 'Arthur': 143, 'As': 144, 'Asia': 145, 'Ask': 146, 'Asylum': 147, 'At': 148, 'Attila': 149, 'Aud': 150, 'August': 151, 'Austrian': 152, 'Authors': 153, 'Avar': 154, 'Away': 155, 'Ay': 156, 'Aërated': 157, 'B': 158, 'BARBICAN': 159, 'BILLINGTON': 160, 'BY': 161, 'Back': 162, 'Backsheesh': 163, 'Bah': 164, 'Bank': 165, 'Bartel': 166, 'Bats': 167, 'Bay': 168, 'Be': 169, 'Because': 170, 'Before': 171, 'Behind': 172, 'Behold': 173, 'Being': 174, 'Believe': 175, 'Berkeley': 176, 'Bermondsey': 177, 'Berserkers': 178, 'Bersicker': 179, 'Besides': 180, 'Bethnal': 181, 'Better': 182, 'Between': 183, 'Beware': 184, 'Beyond': 185, 'Big': 186, 'Bilder': 187, 'Billington': 188, 'Billreuth': 189, 'Biscay': 190, 'Bistritz': 191, 'Bistritza': 192, 'Black': 193, 'Black-Sea-bound': 194, 'Bleeding': 195, 'Bless': 196, 'Blessed': 197, 'Blood': 198, 'Bloofer': 199, 'Blow': 200, 'Bloxam': 201, 'Blue': 202, 'Blyme': 203, 'Board': 204, 'Boarded': 205, 'Borgo': 206, 'Bosphorus': 207, 'Bother': 208, 'Bradshaw': 209, 'Braithwaite': 210, 'Bram': 211, 'Brave': 212, 'Bread': 213, 'Breakfast': 214, 'Bring': 215, 'British': 216, 'Broads': 217, 'Bucharest': 218, 'Buda-Pesth': 219, 'Bukovina': 220, 'Bulgar': 221, 'Burdon-Sanderson': 222, 'Burgen-strasse': 223, 'Burger': 224, 'Burial': 225, 'But': 226, 'By': 227, 'By-and-by': 228, 'Byron': 229, 'C': 230, 'CANDY': 231, 'CARTER': 232, 'CHAPTER': 233, 'CHILD': 234, 'CITY': 235, 'CO': 236, 'COUNTRY': 237, 'COURT': 238, 'CUTTING': 239, 'Caffyn': 240, 'Call': 241, 'Called': 242, 'Campaign': 243, 'Can': 244, 'Candy': 245, 'Cannot': 246, 'Canon': 247, 'Canvas': 248, 'Cape': 249, 'Captain': 250, 'Carfax': 251, 'Carpathian': 252, 'Carpathians': 253, 'Carter': 254, 'Casabianca': 255, 'Casino': 256, 'Cassova': 257, 'Castle': 258, 'Catherine': 259, 'Cattle': 260, 'Certain': 261, 'Certainly': 262, 'Channel': 263, 'Charcot': 264, 'Charing': 265, 'Chasing': 266, 'Chatham': 267, 'Check': 268, 'Chernosese': 269, 'Chicksand': 270, 'China': 271, 'Christian': 272, 'Church': 273, 'Churchman': 274, 'Circus': 275, 'City': 276, 'Cliff': 277, 'Close': 278, 'Closer': 279, 'Co': 280, 'Come': 281, 'Coming': 282, 'Company': 283, 'Complete': 284, 'Confidence': 285, 'Congress': 286,  ...

# %% [markdown]
# # Basic Tokenization
# - Fetched raw text and split it into a token list on whitespace and
#   punctuation, keeping the delimiters as tokens (capturing group in re.split)
# - deduplicated into a set and stripped whitespace/empty entries, then
#   sorted it for stable ordering
# - Enumerated the sorted tokens to build the vocab: {token: id} for encoding
#   (and {id: token} for decoding)
